# %% [markdown]
# # Preprocessing Code for the MERFISH Study
#
# Prepares the MERFISH data based on the analysis by SpatialDE
#
# Requires the SpatialDE package (or the space_met virtualenv)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython.display import display
import sys
import os
import logging

sys.path.insert(0,'../src')
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 100

# %%
import numpy as np
import pandas as pd

import NaiveDE
import SpatialDE

# %%
ddir = '/share/PI/sabatti/sc_data/spatial_ge/spatialde/SpatialDE/Analysis/MERFISH/'

# %%
# load the raw sge data
df = pd.read_csv(ddir+'data/rep6/middle_exp_mat.csv', index_col=0)
print(df.shape)
display(df.head())
sample_info = pd.read_csv(ddir+'data/rep6/middle_sample_info.csv', index_col=0)
display(sample_info.head())
# Out:
# (1056, 140)
#         AFAP1  AFF4  AGAP1  AGO3  AGPS  AHDC1  AKAP11  ALPK2  AMOTL1  ANKH  \
# cellID
# 16345     5.0  11.0   10.0   1.0   5.0    5.0     4.0    6.0     8.0   1.0
# 16347     2.0   1.0    5.0   3.0   2.0    5.0     2.0    6.0     5.0   0.0
# 16348     6.0  12.0   20.0   4.0   8.0    1.0     9.0    4.0    10.0   5.0
# 16349     6.0  11.0   11.0   9.0   9.0   10.0    14.0   17.0     9.0   5.0
# 16351     5.0  12.0   16.0   7.0  10.0    8.0     6.0    7.0    17.0   3.0
#
#         ...  USP34  USP8  USP9X  VPS13D   XDH  XKR5  YIPF4  ZBTB43  ZCCHC6  \
# cellID  ...
# 16345   ...   12.0   6.0   11.0     4.0   8.0   3.0    1.0     6.0     2.0
# 16347   ...   12.0   1.0    8.0     3.0   3.0   1.0    2.0     0.0     2.0
# 16348   ...   11.0   2.0   12.0     4.0   4.0   4.0    5.0     3.0     4.0
# 16349   ...   23.0   3.0   21.0    11.0  16.0  14.0    9.0     7.0    18.0
# 16351   ...   17.0   1.0   15.0     8.0   4.0   1.0    2.0     5.0    15.0
#
#         ZNF592
# cellID
# 16345      3.0
# 16347      5.0
# 16348     12.0
# 16349     10.0
# 16351      4.0
#
# [5 rows x 140 columns]
#              abs_X       abs_Y  nucleusArea  cytoplasmArea  total_count
# cellID
# 16345  -438.999143 -312.475845   193.036072    1040.400991        828.0
# 16347  -437.428582 -334.316858   214.738917     472.263443        557.0
# 16348  -432.656618 -438.886660   276.365457    1083.329695        961.0
# 16349  -429.781788 -411.289794   292.249077    1597.377076       1745.0
# 16351  -412.916125 -358.068636   179.632777     887.384010       1151.0

# %%
df = df.T[df.sum(0) >= 3].T  # Filter practically unobserved genes # doesn't do anything
df = df.loc[sample_info.index]
df.shape
# Out:
# (1056, 140)

# %%
dfm = NaiveDE.stabilize(df.T).T
res = NaiveDE.regress_out(sample_info, dfm.T, 'np.log(total_count)').T
X = sample_info[['abs_X', 'abs_Y']] # coordinates
X.columns = ['x', 'y']
# Add total_count as pseudogene for reference
# res['log_total_count'] = np.log(sample_info['total_count'])

# %%
# save the matrix and the coordinates to file
data_dir = '../data/'
f_pfx = 'MERFISH'
fn_coord = data_dir + '{}_coord.csv'.format(f_pfx)
fn_expr = data_dir + '{}_expr.csv'.format(f_pfx)
res.to_csv(fn_expr)
X.to_csv(fn_coord)

# %%
expr = pd.read_csv(fn_expr, index_col=0)
coor = pd.read_csv(fn_coord, index_col=0)

# %%
coor.head()
# Out:
#                  x           y
# cellID
# 16345  -438.999143 -312.475845
# 16347  -437.428582 -334.316858
# 16348  -432.656618 -438.886660
# 16349  -429.781788 -411.289794
# 16351  -412.916125 -358.068636

# %%
expr.head()
# Out:
#            AFAP1      AFF4     AGAP1      AGO3      AGPS     AHDC1    AKAP11  \
# cellID
# 16345  -4.813842 -3.188008 -3.295723 -4.979079 -4.386973 -4.217989 -4.550988
# 16347  -5.106487 -4.619450 -3.560939 -3.964551 -4.704805 -3.862786 -4.689495
# 16348  -4.807822 -3.234243 -2.778112 -4.207361 -4.122122 -5.429884 -4.000813
# 16349  -5.395198 -3.818007 -3.841525 -4.026636 -4.566920 -4.284435 -4.145430
# 16351  -5.138158 -3.386704 -3.141760 -3.895067 -4.088872 -4.111033 -4.520603
#
#            ALPK2    AMOTL1      ANKH  ...     USP34      USP8     USP9X  \
# cellID                                ...
# 16345  -3.851629 -4.496431 -4.706234  ... -3.845296 -3.461996 -4.570440
# 16347  -3.509033 -4.503137 -5.049473  ... -3.466787 -4.373514 -4.439820
# 16348  -4.313334 -4.445551 -3.748182  ... -4.067165 -4.417784 -4.647323
# 16349  -3.556760 -5.135194 -4.230258  ... -3.946126 -4.616071 -4.750019
# 16351  -4.003824 -4.135164 -4.294359  ... -3.835658 -4.958653 -4.630152
#
#           VPS13D       XDH      XKR5     YIPF4    ZBTB43    ZCCHC6    ZNF592
# cellID
# 16345  -4.146216 -3.051070 -4.715197 -4.041038 -3.420221 -4.964112 -5.160414
# 16347  -4.025982 -3.543440 -5.032331 -3.364482 -4.997824 -4.605185 -4.372846
# 16348  -4.274092 -3.749924 -4.630711 -3.068239 -4.092458 -4.596254 -4.137827
# 16349  -3.917865 -3.001370 -4.083341 -2.984517 -3.884148 -3.810366 -4.886620
# 16351  -3.846620 -3.891029 -5.693100 -3.879179 -3.836398 -3.604869 -5.261995
#
# [5 rows x 140 columns]
