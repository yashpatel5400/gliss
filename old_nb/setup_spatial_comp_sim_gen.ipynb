# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython.display import display
import sys
import os
import logging

sys.path.insert(0,'../src')
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 100

# %%
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

logger = logging.getLogger("feat_viz")
logging.basicConfig(format='[%(name)s %(levelname)s] %(message)s', level=logging.INFO)

# %%
from general_utils import read_spatial_expression, normalize_count_cellranger
from main_methods import select_spatial_genes

# load the data for a given replicate
ddir = '/share/PI/sabatti/sc_data/spatial_ge/scGCO'
ff = ddir + '/data/Raw_data/MERFISH/middle_scGCO_data_matrix.csv'
locs,data=read_spatial_expression(ff,sep=' ')
data_norm = normalize_count_cellranger(data)

# center the locations to zero and 1
loc_df = pd.DataFrame(locs, columns=['x', 'y'])
def center_unit(x):
    shift = (max(x) + min(x)) / 2
    scale = (max(x) - min(x)) / 2
    return (x - shift) / scale
loc_df['x'] = center_unit(loc_df['x'])
loc_df['y'] = center_unit(loc_df['y'])
# Out:
# raw data dim: (1056, 140)

# %%
from plot_utils import plot_multiple_scatter_continuous
plt_df = data_norm[data_norm.columns[:4]]
plot_multiple_scatter_continuous(loc_df, plt_df)

# %%
from sim_utils import add_gaussian_noise, add_uniform_noise
from general_utils import norm_mtx
from sim_utils import gen_2D_pattern, multi_2D_pattern
# plot noiseless templates
temps = ['linear', 'diaquad', 'radial', 'cosine']
seed = 0
for t in temps:
    tdf = multi_2D_pattern(t, loc_df['x'], loc_df['y'])
#     tdf = add_uniform_noise(tdf, 10, seed=seed)
#     tdf = add_gaussian_noise(tdf, 1, seed=seed)
    tdf = pd.DataFrame(tdf)
    plot_multiple_scatter_continuous(loc_df, tdf)

# %%
from io_utils import save_data_to_file
def sim_2D_mtx(loc_df, params):
    n_per_reg = params['n_per_reg']
    n_reg = params['n_regs']
    seed = params['seed']
    t = params['temp']
    
    plot = (seed == 0)
    tdf = multi_2D_pattern(t, loc_df['x'], loc_df['y'], n_regimes=n_reg)
    n_non_nulls = n_per_reg * n_reg
    n_nulls = n_non_nulls
    
    null_mtx = np.zeros((tdf.shape[0], n_nulls))
    nonnull_mtx = np.repeat(tdf, n_per_reg, axis=1)
    mtx = np.concatenate((nonnull_mtx, null_mtx),axis=1)
#     mtx = add_gaussian_noise(mtx, 1, seed=seed)
#     mtx = mtx - np.min(mtx, axis=0)
    mtx = add_gaussian_noise(mtx, 0.1, seed=seed)
    mtx[mtx < 0] = 0
    # plot the non-nulls
    if plot:
        print('Num. of nulls: {}; Num. of non-nulls: {}'.format(n_nulls, n_non_nulls))
        print('Generated matrix: {}'.format(mtx.shape))
        plt_df = pd.DataFrame(mtx[:, ::n_per_reg][:, :(n_reg+1)])
        plot_multiple_scatter_continuous(loc_df, plt_df)
    return mtx

def get_fname(sdir, x, pfx, sfx):
    fn = '{}/{}_{}_{}.{}'.format(sdir, pfx, x['temp'], x['seed'], sfx)
    return fn
    
seeds = list(range(20))
temps = ['linear', 'diaquad', 'radial', 'cosine']

# sim_dir = '/share/PI/sabatti/feat_viz/space_comp_sim/20191030'
sim_dir = '/share/PI/sabatti/feat_viz/space_comp_sim/20191104'

loc_fn = 'locs_2d.csv'
sim_fn = 'sim_setup.csv'
sdir = 'sim_data'

index = pd.MultiIndex.from_product([seeds, temps], names=["seed", "temp"])
sim_df = pd.DataFrame(index = index).reset_index()
sim_df['n_per_reg'] = 25
sim_df['n_regs'] = 4
sim_df['locs_fn'] = loc_fn
sim_df['expr_fn'] = sim_df.apply(lambda x: get_fname(sdir, x, 'mtx', 'csv'), axis=1)
print(sim_df.shape)
display(sim_df.head())

sdir = os.path.join(sim_dir, sdir)
os.makedirs(sdir, exist_ok=True)

loc_fn = os.path.join(sim_dir, loc_fn)
save_data_to_file(loc_df, loc_fn, 'csv')
print('Saved locations to: {}'.format(loc_fn))

sim_fn = os.path.join(sim_dir, sim_fn)
save_data_to_file(sim_df, sim_fn, 'csv')
print('Saved simparams to: {}'.format(sim_fn))
for i, val in sim_df.iterrows():
    mat_df = sim_2D_mtx(loc_df, val)
    mat_df = pd.DataFrame(mat_df)
    fn = os.path.join(sim_dir, val['expr_fn'])
    save_data_to_file(mat_df, fn, 'csv')
    print('Saved matrix to: {}'.format(fn))
# Out:
# (80, 6)
#    seed     temp  n_per_reg  n_regs      locs_fn                     expr_fn
# 0     0   linear         25       4  locs_2d.csv   sim_data/mtx_linear_0.csv
# 1     0  diaquad         25       4  locs_2d.csv  sim_data/mtx_diaquad_0.csv
# 2     0   radial         25       4  locs_2d.csv   sim_data/mtx_radial_0.csv
# 3     0   cosine         25       4  locs_2d.csv   sim_data/mtx_cosine_0.csv
# 4     1   linear         25       4  locs_2d.csv   sim_data/mtx_linear_1.csv
# Saved locations to: /scratch/PI/sabatti/space_comp_sim/20200201/locs_2d.csv
# Saved simparams to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_setup.csv
# Num. of nulls: 100; Num. of non-nulls: 100
# Generated matrix: (1045, 200)
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_0.csv
# Num. of nulls: 100; Num. of non-nulls: 100
# Generated matrix: (1045, 200)
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_0.csv
# Num. of nulls: 100; Num. of non-nulls: 100
# Generated matrix: (1045, 200)
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_0.csv
# Num. of nulls: 100; Num. of non-nulls: 100
# Generated matrix: (1045, 200)
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_0.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_1.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_1.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_1.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_1.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_2.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_2.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_2.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_2.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_3.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_3.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_3.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_3.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_4.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_4.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_4.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_4.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_5.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_5.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_5.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_5.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_6.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_6.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_6.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_6.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_7.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_7.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_7.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_7.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_8.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_8.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_8.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_8.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_9.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_9.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_9.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_9.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_10.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_10.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_10.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_10.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_11.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_11.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_11.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_11.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_12.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_12.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_12.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_12.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_13.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_13.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_13.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_13.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_14.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_14.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_14.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_14.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_15.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_15.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_15.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_15.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_16.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_16.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_16.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_16.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_17.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_17.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_17.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_17.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_18.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_18.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_18.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_18.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_linear_19.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_diaquad_19.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_radial_19.csv
# Saved matrix to: /scratch/PI/sabatti/space_comp_sim/20200201/sim_data/mtx_cosine_19.csv
