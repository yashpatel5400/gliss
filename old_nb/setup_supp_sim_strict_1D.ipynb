# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython.display import display
import sys
import os
import logging
sys.path.insert(0,'../src')
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 100
# mpl.rcParams['text.usetex'] = True

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib.cm as cm
from scipy.stats import spearmanr
from matplotlib import rc
# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
# ## for Palatino and other serif fonts use:
# #rc('font',**{'family':'serif','serif':['Palatino']})
# rc('text', usetex=True)

from plot_utils import plot_ground_truth_heatmap, plot_spike_grps
logger = logging.getLogger("feat_viz")
logging.basicConfig(format='[%(name)s %(levelname)s] %(message)s', level=logging.INFO)

# %% [markdown]
# ## Setup the actual simulation and slurm jobs

# %%
from sim_utils import load_regime_feat_sel, launch_regime_feat_sel
from sim_utils import generate_regime_info, get_regime_info, create_trial_jobs
sim_id = "main_sim_strict_1"
generate_regime_info(sim_id)
df_regime = get_regime_info(sim_id)
create_trial_jobs(sim_id)
display(df_regime)
# Out:
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] {'seed': 0, 'n_samps': None, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 50, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 80, 'method': None, 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76]}
# [feat_viz INFO] Saved regimes to: /share/PI/sabatti/feat_viz/main_sim_strict_1/regime_info.csv
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] Created: /share/PI/sabatti/feat_viz/main_sim_strict_1/regime_results/regime_0/slurm_job.sh
# [feat_viz INFO] Created: /share/PI/sabatti/feat_viz/main_sim_strict_1/regime_results/regime_1/slurm_job.sh
# [feat_viz INFO] Created: /share/PI/sabatti/feat_viz/main_sim_strict_1/regime_results/regime_2/slurm_job.sh
# [feat_viz INFO] Created: /share/PI/sabatti/feat_viz/main_sim_strict_1/regime_results/regime_3/slurm_job.sh
# [feat_viz INFO] Created: /share/PI/sabatti/feat_viz/main_sim_strict_1/regime_results/regime_4/slurm_job.sh
# [feat_viz INFO] Launch all the slurm jobs with the following command:
# bash /share/PI/sabatti/feat_viz/main_sim_strict_1/launch_all.sh
#    n_samps  n_trials
# 0      500        50
# 1     1000        50
# 2     1500        50
# 3     2000        50
# 4     5000        50

# %%
from sim_utils import launch_strict_order_pipeline
launch_strict_order_pipeline(sim_id, 0, test=True)
# Out:
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] {'seed': 0, 'n_samps': 500, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': None, 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] {'seed': 0, 'n_samps': 500, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'pc', 'graph_k': -1, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] curr. score 0.840477 aug-dim: (500, 0)
# [feat_viz INFO] curr. score 0.877549 aug-dim: (500, 4)
# [feat_viz INFO] curr. score 0.907062 aug-dim: (500, 8)
# [feat_viz INFO] curr. score 0.905965 aug-dim: (500, 12)
# [feat_viz INFO] curr. score 0.903784 aug-dim: (500, 16)
# [feat_viz INFO] curr. score 0.903856 aug-dim: (500, 20)
# [feat_viz INFO] curr. score 0.892446 aug-dim: (500, 24)
# [feat_viz INFO] curr. score 0.892232 aug-dim: (500, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.892072 aug-dim: (500, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.891868 aug-dim: (500, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.891388 aug-dim: (500, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.891016 aug-dim: (500, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.890861 aug-dim: (500, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.891775 aug-dim: (500, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.890671 aug-dim: (500, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.889124 aug-dim: (500, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.889750 aug-dim: (500, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.889589 aug-dim: (500, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.889757 aug-dim: (500, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.890115 aug-dim: (500, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.889913 aug-dim: (500, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.889470 aug-dim: (500, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.888252 aug-dim: (500, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.885982 aug-dim: (500, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.884247 aug-dim: (500, 96) (*72 nulls)
# [feat_viz INFO] Trial used 0.55s
# [feat_viz INFO] {'seed': 0, 'n_samps': 500, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'graph', 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] curr. score 0.840410 aug-dim: (500, 0)
# [feat_viz INFO] curr. score 0.866310 aug-dim: (500, 4)
# [feat_viz INFO] curr. score 0.904607 aug-dim: (500, 8)
# [feat_viz INFO] curr. score 0.928857 aug-dim: (500, 12)
# [feat_viz INFO] curr. score 0.934315 aug-dim: (500, 16)
# [feat_viz INFO] curr. score 0.933263 aug-dim: (500, 20)
# [feat_viz INFO] curr. score 0.940797 aug-dim: (500, 24)
# [feat_viz INFO] curr. score 0.936872 aug-dim: (500, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.936912 aug-dim: (500, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.937583 aug-dim: (500, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.939965 aug-dim: (500, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.927292 aug-dim: (500, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.925034 aug-dim: (500, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.922695 aug-dim: (500, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.923232 aug-dim: (500, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.923622 aug-dim: (500, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.917141 aug-dim: (500, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.921291 aug-dim: (500, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.917398 aug-dim: (500, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.911909 aug-dim: (500, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.908329 aug-dim: (500, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.906927 aug-dim: (500, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.908077 aug-dim: (500, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.900775 aug-dim: (500, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.904509 aug-dim: (500, 96) (*72 nulls)
# [feat_viz INFO] Trial used 2.98s
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] {'seed': 1, 'n_samps': 500, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': None, 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] {'seed': 1, 'n_samps': 500, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'pc', 'graph_k': -1, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] curr. score 0.840203 aug-dim: (500, 0)
# [feat_viz INFO] curr. score 0.881420 aug-dim: (500, 4)
# [feat_viz INFO] curr. score 0.900157 aug-dim: (500, 8)
# [feat_viz INFO] curr. score 0.900705 aug-dim: (500, 12)
# [feat_viz INFO] curr. score 0.900552 aug-dim: (500, 16)
# [feat_viz INFO] curr. score 0.899259 aug-dim: (500, 20)
# [feat_viz INFO] curr. score 0.903532 aug-dim: (500, 24)
# [feat_viz INFO] curr. score 0.903962 aug-dim: (500, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.902124 aug-dim: (500, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.900718 aug-dim: (500, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.901059 aug-dim: (500, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.900354 aug-dim: (500, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.900567 aug-dim: (500, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.899831 aug-dim: (500, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.899353 aug-dim: (500, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.899005 aug-dim: (500, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.899114 aug-dim: (500, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.898047 aug-dim: (500, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.897407 aug-dim: (500, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.896706 aug-dim: (500, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.896620 aug-dim: (500, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.897828 aug-dim: (500, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.897286 aug-dim: (500, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.896349 aug-dim: (500, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.896226 aug-dim: (500, 96) (*72 nulls)
# [feat_viz INFO] Trial used 0.49s
# [feat_viz INFO] {'seed': 1, 'n_samps': 500, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'graph', 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] curr. score 0.842523 aug-dim: (500, 0)
# [feat_viz INFO] curr. score 0.874467 aug-dim: (500, 4)
# [feat_viz INFO] curr. score 0.889848 aug-dim: (500, 8)
# [feat_viz INFO] curr. score 0.920307 aug-dim: (500, 12)
# [feat_viz INFO] curr. score 0.940401 aug-dim: (500, 16)
# [feat_viz INFO] curr. score 0.949269 aug-dim: (500, 20)
# [feat_viz INFO] curr. score 0.950599 aug-dim: (500, 24)
# [feat_viz INFO] curr. score 0.947391 aug-dim: (500, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.940156 aug-dim: (500, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.934988 aug-dim: (500, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.934543 aug-dim: (500, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.936459 aug-dim: (500, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.934773 aug-dim: (500, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.931272 aug-dim: (500, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.928966 aug-dim: (500, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.928054 aug-dim: (500, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.927415 aug-dim: (500, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.920701 aug-dim: (500, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.920900 aug-dim: (500, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.921360 aug-dim: (500, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.911763 aug-dim: (500, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.909970 aug-dim: (500, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.909808 aug-dim: (500, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.912905 aug-dim: (500, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.908106 aug-dim: (500, 96) (*72 nulls)
# [feat_viz INFO] Trial used 2.73s

# %%
launch_strict_order_pipeline(sim_id, 4, test=True)
# Out:
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] {'seed': 0, 'n_samps': 5000, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': None, 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] {'seed': 0, 'n_samps': 5000, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'pc', 'graph_k': -1, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] curr. score 0.844017 aug-dim: (5000, 0)
# [feat_viz INFO] curr. score 0.866031 aug-dim: (5000, 4)
# [feat_viz INFO] curr. score 0.893539 aug-dim: (5000, 8)
# [feat_viz INFO] curr. score 0.893517 aug-dim: (5000, 12)
# [feat_viz INFO] curr. score 0.893538 aug-dim: (5000, 16)
# [feat_viz INFO] curr. score 0.892980 aug-dim: (5000, 20)
# [feat_viz INFO] curr. score 0.890367 aug-dim: (5000, 24)
# [feat_viz INFO] curr. score 0.890400 aug-dim: (5000, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.890336 aug-dim: (5000, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.890213 aug-dim: (5000, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.890187 aug-dim: (5000, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.890084 aug-dim: (5000, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.890096 aug-dim: (5000, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.890034 aug-dim: (5000, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.890067 aug-dim: (5000, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.890078 aug-dim: (5000, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.890097 aug-dim: (5000, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.890142 aug-dim: (5000, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.890077 aug-dim: (5000, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.890009 aug-dim: (5000, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.889871 aug-dim: (5000, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.889905 aug-dim: (5000, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.889902 aug-dim: (5000, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.890033 aug-dim: (5000, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.890056 aug-dim: (5000, 96) (*72 nulls)
# [feat_viz INFO] Trial used 73.38s
# [feat_viz INFO] {'seed': 0, 'n_samps': 5000, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'graph', 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] curr. score 0.846404 aug-dim: (5000, 0)
# [feat_viz INFO] curr. score 0.869451 aug-dim: (5000, 4)
# [feat_viz INFO] curr. score 0.892220 aug-dim: (5000, 8)
# [feat_viz INFO] curr. score 0.924940 aug-dim: (5000, 12)
# [feat_viz INFO] curr. score 0.940778 aug-dim: (5000, 16)
# [feat_viz INFO] curr. score 0.948377 aug-dim: (5000, 20)
# [feat_viz INFO] curr. score 0.954647 aug-dim: (5000, 24)
# [feat_viz INFO] curr. score 0.951772 aug-dim: (5000, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.948802 aug-dim: (5000, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.945649 aug-dim: (5000, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.945210 aug-dim: (5000, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.943546 aug-dim: (5000, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.941695 aug-dim: (5000, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.938354 aug-dim: (5000, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.938484 aug-dim: (5000, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.935968 aug-dim: (5000, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.935531 aug-dim: (5000, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.932696 aug-dim: (5000, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.931083 aug-dim: (5000, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.928675 aug-dim: (5000, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.927739 aug-dim: (5000, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.926009 aug-dim: (5000, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.922969 aug-dim: (5000, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.921737 aug-dim: (5000, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.919663 aug-dim: (5000, 96) (*72 nulls)
# [feat_viz INFO] Trial used 1281.54s
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] {'seed': 1, 'n_samps': 5000, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': None, 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] {'seed': 1, 'n_samps': 5000, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'pc', 'graph_k': -1, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] curr. score 0.849070 aug-dim: (5000, 0)
# [feat_viz INFO] curr. score 0.872707 aug-dim: (5000, 4)
# [feat_viz INFO] curr. score 0.897485 aug-dim: (5000, 8)
# [feat_viz INFO] curr. score 0.897475 aug-dim: (5000, 12)
# [feat_viz INFO] curr. score 0.897448 aug-dim: (5000, 16)
# [feat_viz INFO] curr. score 0.892788 aug-dim: (5000, 20)
# [feat_viz INFO] curr. score 0.892543 aug-dim: (5000, 24)
# [feat_viz INFO] curr. score 0.892503 aug-dim: (5000, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.892474 aug-dim: (5000, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.892350 aug-dim: (5000, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.891894 aug-dim: (5000, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.891770 aug-dim: (5000, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.891726 aug-dim: (5000, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.891726 aug-dim: (5000, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.891738 aug-dim: (5000, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.891764 aug-dim: (5000, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.891714 aug-dim: (5000, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.891562 aug-dim: (5000, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.891592 aug-dim: (5000, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.891534 aug-dim: (5000, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.891290 aug-dim: (5000, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.891364 aug-dim: (5000, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.891332 aug-dim: (5000, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.891228 aug-dim: (5000, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.891218 aug-dim: (5000, 96) (*72 nulls)
# [feat_viz INFO] Trial used 70.61s
# [feat_viz INFO] {'seed': 1, 'n_samps': 5000, 'n_samps_list': [500, 1000, 1500, 2000, 5000], 'n_trials': 100, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'graph', 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96]}
# [feat_viz INFO] curr. score 0.849072 aug-dim: (5000, 0)
# [feat_viz INFO] curr. score 0.870995 aug-dim: (5000, 4)
# [feat_viz INFO] curr. score 0.895045 aug-dim: (5000, 8)
# [feat_viz INFO] curr. score 0.927153 aug-dim: (5000, 12)
# [feat_viz INFO] curr. score 0.944424 aug-dim: (5000, 16)
# [feat_viz INFO] curr. score 0.948572 aug-dim: (5000, 20)
# [feat_viz INFO] curr. score 0.955170 aug-dim: (5000, 24)
# [feat_viz INFO] curr. score 0.952537 aug-dim: (5000, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.951707 aug-dim: (5000, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.948635 aug-dim: (5000, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.944839 aug-dim: (5000, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.942748 aug-dim: (5000, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.941262 aug-dim: (5000, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.937672 aug-dim: (5000, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.937926 aug-dim: (5000, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.935958 aug-dim: (5000, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.934284 aug-dim: (5000, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.932999 aug-dim: (5000, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.932797 aug-dim: (5000, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.930095 aug-dim: (5000, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.930497 aug-dim: (5000, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.930101 aug-dim: (5000, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.926221 aug-dim: (5000, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.925997 aug-dim: (5000, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.925106 aug-dim: (5000, 96) (*72 nulls)
# [feat_viz INFO] Trial used 1248.78s

# %% [markdown]
# ## An example of a simulation trial
#
# ### Insights:
#
# - The most exaggerated paramters include "mid" within the initial variables (such that more of these then left-right)
# - Most dramatic changes happen when "mid" is included

# %%
# Core simulation parameters
from sim_utils import get_sim_params, generate_synthetic_data
# FDIR="/scratch/users/jjzhu/20190415_featviz/simulation/latent_strict_order_recovery"
# --------------------------------------------------------------------
# REDUCE THE NUMBER OF NULL VARIABLES FOR EFFICIENCY
# params = get_sim_params("main_sim_strict_1")
# params["target_vars"] = 100
# target_vars = params["target_vars"]
# rep_unit = 1 # params["y_param"]["n_repetitions"]
# params["n_var_list"] = np.arange(0, target_vars, rep_unit).astype(int)
# --------------------------------------------------------------------
sim_params = get_sim_params("main_sim_strict_1")
plot_spike_grps(sim_params["x_param"]["spike_grp"], 
                sim_params["x_param"]["rel_noise_list"] + [1e-2, 1e-9])
#                 fn=os.path.join(FDIR, "x_struct.png"))
plot_spike_grps(sim_params["y_param"]["spike_grp"], 
                sim_params["y_param"]["rel_noise_list"] + [1e-2, 1e-9])
#                 fn=os.path.join(FDIR, "y_struct.png"))
logger.info("{}".format(sim_params["n_var_list"]))
lam, x_mtx, y_mtx, n_mtx = generate_synthetic_data(sim_params)
cand_mtx = np.concatenate([y_mtx, n_mtx], axis=1)
plot_ground_truth_heatmap(lam, cand_mtx)
# Out:
# [feat_viz INFO] sim. dir. /share/PI/sabatti/feat_viz/main_sim_strict_1
# [feat_viz INFO] [ 0  4  8 12 16 20 24 28 32 36 40 44 48 52 56 60 64 68 72 76 80 84 88 92
#  96]
# [feat_viz INFO] {'seed': 0, 'n_samps': 1500, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': None, 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': array([ 0,  4,  8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64,
#        68, 72, 76, 80, 84, 88, 92, 96])}

# %%
from sim_utils import run_strict_order_analysis
sim_params["method"] = "pc"
sim_params["graph_k"] = -1
df_pc, aux_pc = run_strict_order_analysis(lam, x_mtx, y_mtx, n_mtx, sim_params)
sim_params["method"] = "graph"
sim_params["graph_k"] = 10
df_graph, aux_graph = run_strict_order_analysis(lam, x_mtx, y_mtx, n_mtx, sim_params)
df_pc["method"] = "pca"
df_graph["method"] = "graph"
df_tot = pd.concat([df_pc, df_graph])
# Out:
# [feat_viz INFO] {'seed': 0, 'n_samps': 1500, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'pc', 'graph_k': -1, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': array([ 0,  4,  8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64,
#        68, 72, 76, 80, 84, 88, 92, 96])}
# [feat_viz INFO] curr. score 0.846280 aug-dim: (1500, 0)
# [feat_viz INFO] curr. score 0.868583 aug-dim: (1500, 4)
# [feat_viz INFO] curr. score 0.893134 aug-dim: (1500, 8)
# [feat_viz INFO] curr. score 0.893427 aug-dim: (1500, 12)
# [feat_viz INFO] curr. score 0.893285 aug-dim: (1500, 16)
# [feat_viz INFO] curr. score 0.893685 aug-dim: (1500, 20)
# [feat_viz INFO] curr. score 0.894482 aug-dim: (1500, 24)
# [feat_viz INFO] curr. score 0.894049 aug-dim: (1500, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.894128 aug-dim: (1500, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.893660 aug-dim: (1500, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.893948 aug-dim: (1500, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.893843 aug-dim: (1500, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.893533 aug-dim: (1500, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.893490 aug-dim: (1500, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.893073 aug-dim: (1500, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.892818 aug-dim: (1500, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.892806 aug-dim: (1500, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.891914 aug-dim: (1500, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.891755 aug-dim: (1500, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.891837 aug-dim: (1500, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.892086 aug-dim: (1500, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.892026 aug-dim: (1500, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.891930 aug-dim: (1500, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.891965 aug-dim: (1500, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.891795 aug-dim: (1500, 96) (*72 nulls)
# [feat_viz INFO] Trial used 3.26s
# [feat_viz INFO] {'seed': 0, 'n_samps': 1500, 'x_param': {'spike_grp': ['left', 'right'], 'n_repetitions': 1, 'rel_noise_list': [1, 0.1]}, 'y_param': {'spike_grp': ['right', 'left', 'mid', 'mid_r', 'multi_left', 'multi_right'], 'n_repetitions': 4, 'rel_noise_list': [0.5]}, 'target_vars': 100, 'method': 'graph', 'graph_k': 10, 'sim_dir': '/share/PI/sabatti/feat_viz/main_sim_strict_1', 'n_var_list': array([ 0,  4,  8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64,
#        68, 72, 76, 80, 84, 88, 92, 96])}
# [feat_viz INFO] curr. score 0.841186 aug-dim: (1500, 0)
# [feat_viz INFO] curr. score 0.868297 aug-dim: (1500, 4)
# [feat_viz INFO] curr. score 0.886332 aug-dim: (1500, 8)
# [feat_viz INFO] curr. score 0.925855 aug-dim: (1500, 12)
# [feat_viz INFO] curr. score 0.942338 aug-dim: (1500, 16)
# [feat_viz INFO] curr. score 0.948516 aug-dim: (1500, 20)
# [feat_viz INFO] curr. score 0.958221 aug-dim: (1500, 24)
# [feat_viz INFO] curr. score 0.953565 aug-dim: (1500, 28) (*4 nulls)
# [feat_viz INFO] curr. score 0.949410 aug-dim: (1500, 32) (*8 nulls)
# [feat_viz INFO] curr. score 0.945414 aug-dim: (1500, 36) (*12 nulls)
# [feat_viz INFO] curr. score 0.940459 aug-dim: (1500, 40) (*16 nulls)
# [feat_viz INFO] curr. score 0.936232 aug-dim: (1500, 44) (*20 nulls)
# [feat_viz INFO] curr. score 0.933859 aug-dim: (1500, 48) (*24 nulls)
# [feat_viz INFO] curr. score 0.935275 aug-dim: (1500, 52) (*28 nulls)
# [feat_viz INFO] curr. score 0.934315 aug-dim: (1500, 56) (*32 nulls)
# [feat_viz INFO] curr. score 0.931528 aug-dim: (1500, 60) (*36 nulls)
# [feat_viz INFO] curr. score 0.929721 aug-dim: (1500, 64) (*40 nulls)
# [feat_viz INFO] curr. score 0.924574 aug-dim: (1500, 68) (*44 nulls)
# [feat_viz INFO] curr. score 0.924308 aug-dim: (1500, 72) (*48 nulls)
# [feat_viz INFO] curr. score 0.922256 aug-dim: (1500, 76) (*52 nulls)
# [feat_viz INFO] curr. score 0.921311 aug-dim: (1500, 80) (*56 nulls)
# [feat_viz INFO] curr. score 0.917781 aug-dim: (1500, 84) (*60 nulls)
# [feat_viz INFO] curr. score 0.918064 aug-dim: (1500, 88) (*64 nulls)
# [feat_viz INFO] curr. score 0.918554 aug-dim: (1500, 92) (*68 nulls)
# [feat_viz INFO] curr. score 0.914171 aug-dim: (1500, 96) (*72 nulls)
# [feat_viz INFO] Trial used 40.72s

# %%
grouped = df_tot.groupby("method")
fig, ax = plt.subplots(figsize=(5.5,4))
for key,group in grouped:
    group.plot(x="n_cand", y="corr", label=key,
               marker="o", linestyle='dashed', ax=ax)
ax.set_xlabel("number of included variables (in strict order)")
ax.set_ylabel("Spearman's correlation between $\lambda$ and $\hat{\lambda}$")
# fn = os.path.join(FDIR, "compare_graph_pc.pdf")
# if fn:
#     plt.savefig(fn, bbox_inches='tight') 
#     logger.info("Saved figure to: {}".format(fn))    
plt.show()

# %% [markdown]
# ### Evaluate the correlation metrics

# %%
fig, ax = plt.subplots(figsize=(9,4))
ax = sns.heatmap(aux_pc["sel_scores"])
ax.set_ylabel("iteration with increasing model size")
ax.set_xlabel("response variables (strictly ordered)")
# fn = os.path.join(FDIR, "heatmap_pc_corr_score.png")
# plt.savefig(fn, bbox_inches='tight')
# logger.info("Saved: {}".format(fn))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,4))
ax = sns.heatmap(aux_graph["sel_scores"])
ax.set_ylabel("iteration with increasing model size")
ax.set_xlabel("response variables (strictly ordered)")
# fn = os.path.join(FDIR, "heatmap_graph_lap_score.png")
# plt.savefig(fn, bbox_inches='tight')
# logger.info("Saved: {}".format(fn))
plt.show()
